# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

fp = open('data/a.html')
html = BeautifulSoup(fp, 'html.parser')
html
# Out:
# <html>
# <body>
# <h1>테스트1</h1>
# <h1 class="my">테스트2</h1>
# <h1 id="myh2">테스트3</h1>
# <h2>테스트3-1</h2>
# <div id="mydiv">
# <span class="my">테스트4</span>
# <div><span>테스트5</span></div>
# </div>
# <ul class="fruit">
# <li>사과</li>
# <li>딸기</li>
# <li>포도</li>
# </ul>
# <ul class="biz">
# <li>회사1</li>
# <li>회사2</li>
# <li>회사3</li>
# </ul>
# <img src="a.jpg"/><br/>
# <img src="b.jpg"/>
# </body>
# </html>

# %%
html.h1
# Out:
# <h1>테스트1</h1>

# %%
# Out:
# []

# %% [markdown]
# # Tag selector (엘리먼트명)
# - html.select_one('selector') # 첫번째 엘리먼트
# - html.select('selector') # all element

# %%
html.select_one('h1')
# Out:
# <h1>테스트1</h1>

# %%
html.select('h1')
# Out:
# [<h1>테스트1</h1>, <h1 class="my">테스트2</h1>, <h1 id="myh2">테스트3</h1>]

# %% [markdown]
# 복수개 선택 , 사용

# %%
html.select('h1, h2')
# Out:
# [<h1>테스트1</h1>,
#  <h1 class="my">테스트2</h1>,
#  <h1 id="myh2">테스트3</h1>,
#  <h2>테스트3-1</h2>]

# %%
for n in html.select('h1, h2'):
    print(n.string) # 텍스트 뽑아오기
# Out:
# 테스트1
# 테스트2
# 테스트3
# 테스트3-1

# %% [markdown]
# ### html tag의 id 선택자  : (#)

# %%
html.select('#mydiv')
# Out:
# [<div id="mydiv">
#  <span class="my">테스트4</span>
#  <div><span>테스트5</span></div>
#  </div>]

# %% [markdown]
# ### 클래스 선택자 : .

# %%
html.select('h1.my')
# h1 엘리먼트 and 클래스 속성이 my
# Out:
# [<h1 class="my">테스트2</h1>]

# %%
html.select('h1,.my')
# h1 엘리먼트 Or 클래스 속성이 my
# Out:
# [<h1>테스트1</h1>,
#  <h1 class="my">테스트2</h1>,
#  <h1 id="myh2">테스트3</h1>,
#  <span class="my">테스트4</span>]

# %% [markdown]
# ### 속성 선택자 : []

# %%
html.select('[src]') # src property가 있는것
# Out:
# [<img src="a.jpg"/>, <img src="b.jpg"/>]

# %%
html.select('[src="a.jpg"]') # src 속성이 a.jpg
# Out:
# [<img src="a.jpg"/>]

# %%
html.select( '[src*="jpg"]') # *= src 속성 값에 jpg가 있는 것
# Out:
# [<img src="a.jpg"/>, <img src="b.jpg"/>]

# %% [markdown]
# ### 자식 선택자 : >

# %%
html.select( '#mydiv')
# Out:
# [<div id="mydiv">
#  <span class="my">테스트4</span>
#  <div><span>테스트5</span></div>
#  </div>]

# %%
html.select( '#mydiv > span')
# Out:
# [<span class="my">테스트4</span>]

# %% [markdown]
# ### 후손 선택자 : 공백

# %%
html.select( '#mydiv span')
# Out:
# [<span class="my">테스트4</span>, <span>테스트5</span>]

# %%
# 사과 딸기 포도
html.select( '.fruit > li')
#html
# Out:
# [<li>사과</li>, <li>딸기</li>, <li>포도</li>]

# %%
html.select( '.fruit > li:nth-child(1)')
# Out:
# [<li>사과</li>]

# %%
html.select('li')
# Out:
# [<li>사과</li>,
#  <li>딸기</li>,
#  <li>포도</li>,
#  <li>회사1</li>,
#  <li>회사2</li>,
#  <li>회사3</li>]

# %% [markdown]
# # 웹에서 읽어오자

# %% [markdown]
# ### 맛집데이터 파싱

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

murl = 'https://www.menupan.com/restaurant/bestrest/bestrest.asp?pt=rt&areacode=ss201'
response = urlopen( murl )
html = BeautifulSoup( response, 'html.parser' )
html
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>맛집TOP1000 - 매일매일 맛있게 메뉴판닷컴</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/common/css/default.css" rel="stylesheet" type="text/css"/>
# <link href="/common/style/restaurant/bestrest.css" rel="stylesheet" type="text/css"/>
# <script language="javascript" src="/script/jquery/jquery-latest.min.js"></script>
# <script language="javascript">
# 	<!--
# 		//-- hide all layer
# 		function fn_close_all_layer() {
# 			fn_disp_layer_standard('hide');
# 			fn_disp_layer_type('hide');
# 		}
# 		//-- show information
# 		function fn_disp_layer_standard(p_cmd) {
# 			if (p_cmd == 'show') {
# 				fn_close_all_layer();
# 				$('#id_lyr_standard').show();
# 			}
# 			else if (p_cmd == 'hide') {
# 				$('#id_lyr_standard').hide();
# 			}
# 		}
# 		//-- show type select
# ...

# %%
# body > div > div.container > div.bestRest > div.ranking > div.rankingList > ul
uI = html.select_one('div.rankingList > ul')
for li in uI.select('li'):    
    print('순위 : ', li.select_one('.numTop,.rankNum').string )
    print('상호 : ', li.select_one('.restName > a').string )
    print('업종 : ', li.select_one('.listType').string )
    print('지역 : ', li.select_one('.listArea').string )
# Out:
# 순위 :  1
# 상호 :  스시에비뉴(Sushi Avenue)
# 업종 :  뷔페
# 업종 :  강남구 역삼동
# 순위 :  2
# 상호 :  참설농탕
# 업종 :  한식
# 업종 :  서초구 서초동
# 순위 :  3
# 상호 :  아카사카
# 업종 :  일식
# 업종 :  서초구 서초동
# 순위 :  4
# 상호 :  진상 서초본점
# 업종 :  일식
# 업종 :  서초구 서초동
# 순위 :  5
# 상호 :  화기애애
# 업종 :  한식
# 업종 :  강남구 역삼동
# 순위 :  6
# 상호 :  도모다찌
# 업종 :  일식
# 업종 :  강남구 역삼동
# 순위 :  7
# 상호 :  평가옥 반포점
# 업종 :  한식
# 업종 :  서초구 반포동
# 순위 :  8
# 상호 :  딘타이펑 강남역점
# 업종 :  중식
# 업종 :  서초구 서초동
# 순위 :  9
# 상호 :  연타발 강남역점
# 업종 :  한식
# 업종 :  서초구 서초동
# 순위 :  10
# 상호 :  유희
# 업종 :  카페/주점
# 업종 :  서초구 서초4동
# 순위 :  11
# 상호 :  런드리피자(LAUNDRY PIZZA)
# 업종 :  패스트푸드
# 업종 :  강남구 역삼동
# 순위 :  12
# 상호 :  이제이베이킹스튜디오
# 업종 :  카페/주점
# 업종 :  강남구 역삼동
# 순위 :  13
# 상호 :  갓덴스시 강남점
# 업종 :  일식
# 업종 :  강남구 역삼동
# 순위 :  14
# 상호 :  삼호복집
# 업종 :  한식
# 업종 :  서초구 서초2동
# 순위 :  15
# 상호 :  더수제비(The수제비)
# 업종 :  한식
# 업종 :  강남구 역삼동
# 순위 :  16
# 상호 :  딸부자네불백 강남역점
# 업종 :  한식
# 업종 :  강남구 역삼동
# 순위 :  17
# 상호 :  악바리
# 업종 :  카페/주점
# 업종 :  서초구 서초동
# 순위 :  18
# 상호 :  원조원주추어탕
# 업종 :  한식
# 업종 :  강남구 역삼동
# ...

# %%
# body > div > div.container > div.bestRest > div.ranking > div.rankingList > ul
mList = []
uI = html.select_one('div.rankingList > ul')
for li in uI.select('li'):    
    mList.append({
        '순위': li.select_one('.numTop,.rankNum').string,
        '상호': li.select_one('.restName > a').string,
        '업종': li.select_one('.listType').string,
        '지역': li.select_one('.listArea').string
    })
mList
# Out:
# [{'순위': '1', '상호': '스시에비뉴(Sushi Avenue)', '업종': '뷔페', '지역': '강남구 역삼동'},
#  {'순위': '2', '상호': '참설농탕', '업종': '한식', '지역': '서초구 서초동'},
#  {'순위': '3', '상호': '아카사카', '업종': '일식', '지역': '서초구 서초동'},
#  {'순위': '4', '상호': '진상 서초본점', '업종': '일식', '지역': '서초구 서초동'},
#  {'순위': '5', '상호': '화기애애', '업종': '한식', '지역': '강남구 역삼동'},
#  {'순위': '6', '상호': '도모다찌', '업종': '일식', '지역': '강남구 역삼동'},
#  {'순위': '7', '상호': '평가옥 반포점', '업종': '한식', '지역': '서초구 반포동'},
#  {'순위': '8', '상호': '딘타이펑 강남역점', '업종': '중식', '지역': '서초구 서초동'},
#  {'순위': '9', '상호': '연타발 강남역점', '업종': '한식', '지역': '서초구 서초동'},
#  {'순위': '10', '상호': '유희', '업종': '카페/주점', '지역': '서초구 서초4동'},
#  {'순위': '11', '상호': '런드리피자(LAUNDRY PIZZA)', '업종': '패스트푸드', '지역': '강남구 역삼동'},
#  {'순위': '12', '상호': '이제이베이킹스튜디오', '업종': '카페/주점', '지역': '강남구 역삼동'},
#  {'순위': '13', '상호': '갓덴스시 강남점', '업종': '일식', '지역': '강남구 역삼동'},
#  {'순위': '14', '상호': '삼호복집', '업종': '한식', '지역': '서초구 서초2동'},
#  {'순위': '15', '상호': '더수제비(The수제비)', '업종': '한식', '지역': '강남구 역삼동'},
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

menuDF = pd.DataFrame(mList)
menuDF.set_index('순위', inplace=True)
menuDF
# Out:
#                       상호     업종        지역
# 순위
# 1    스시에비뉴(Sushi Avenue)     뷔페   강남구 역삼동
# 2                   참설농탕     한식   서초구 서초동
# 3                   아카사카     일식   서초구 서초동
# 4                진상 서초본점     일식   서초구 서초동
# 5                   화기애애     한식   강남구 역삼동
# 6                   도모다찌     일식   강남구 역삼동
# 7                평가옥 반포점     한식   서초구 반포동
# 8              딘타이펑 강남역점     중식   서초구 서초동
# 9               연타발 강남역점     한식   서초구 서초동
# 10                    유희  카페/주점  서초구 서초4동
# 11  런드리피자(LAUNDRY PIZZA)  패스트푸드   강남구 역삼동
# 12            이제이베이킹스튜디오  카페/주점   강남구 역삼동
# 13              갓덴스시 강남점     일식   강남구 역삼동
# 14                  삼호복집     한식  서초구 서초2동
# 15          더수제비(The수제비)     한식   강남구 역삼동
# 16           딸부자네불백 강남역점     한식   강남구 역삼동
# 17                   악바리  카페/주점   서초구 서초동
# 18               원조원주추어탕     한식   강남구 역삼동
# 19                   한도니     한식   강남구 역삼동
# 20             무월(muwol)     한식   강남구 역삼동
# 21            홍콩반점 서초교보점     중식   서초구 서초동
# ...

# %%
# 지역이 역삼동
menuDF[menuDF['지역'].str.contains('강남구 역삼동')]
# Out:
#                       상호     업종       지역
# 순위
# 1    스시에비뉴(Sushi Avenue)     뷔페  강남구 역삼동
# 5                   화기애애     한식  강남구 역삼동
# 6                   도모다찌     일식  강남구 역삼동
# 11  런드리피자(LAUNDRY PIZZA)  패스트푸드  강남구 역삼동
# 12            이제이베이킹스튜디오  카페/주점  강남구 역삼동
# 13              갓덴스시 강남점     일식  강남구 역삼동
# 15          더수제비(The수제비)     한식  강남구 역삼동
# 16           딸부자네불백 강남역점     한식  강남구 역삼동
# 18               원조원주추어탕     한식  강남구 역삼동
# 19                   한도니     한식  강남구 역삼동
# 20             무월(muwol)     한식  강남구 역삼동
# 22                일품각양꼬치     중식  강남구 역삼동
# 23                회뜨는사나이  카페/주점  강남구 역삼동
# 25             와인코르크 강남점  카페/주점  강남구 역삼동

# %%
# 업종이 한식
menuDF[menuDF['업종'].str.contains('한식')]
# Out:
#                   상호  업종        지역
# 순위
# 2               참설농탕  한식   서초구 서초동
# 5               화기애애  한식   강남구 역삼동
# 7            평가옥 반포점  한식   서초구 반포동
# 9           연타발 강남역점  한식   서초구 서초동
# 14              삼호복집  한식  서초구 서초2동
# 15      더수제비(The수제비)  한식   강남구 역삼동
# 16       딸부자네불백 강남역점  한식   강남구 역삼동
# 18           원조원주추어탕  한식   강남구 역삼동
# 19               한도니  한식   강남구 역삼동
# 20         무월(muwol)  한식   강남구 역삼동
# 24  명동부대찌개명동황기족발 강남점  한식   서초구 서초동

# %%
# !pip install folium

# %% [markdown]
# # 지도 map

# %%
import folium
map = folium.Map(location=(37.56779192326431, 126.97796655262968), zoom_start=14)
mk = folium.Marker(location=(37.565730201564996, 126.97804448113926), popup='서울시청')
mk.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
